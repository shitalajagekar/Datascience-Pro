# %%
some_func <- function(x) {
    x
}

# %%
some_func("Hello R")
# Out:
# [1] "Hello R"

# %%
z<- c(1,2,3)

# %%
mean(z)
# Out:
# [1] 2

# %%
sum(z)
# Out:
# [1] 6

# %%
length(z)
# Out:
# [1] 3

# %%
sum(z)/length(z)
# Out:
# [1] 2

# %%
my_mean <- function(x){
    sum(x)/length(x)
}

# %%
my_mean(c(1,2,3))
# Out:
# [1] 2

# %%
my_mean(c("a","a","a"))
# Out:
# Error in sum(x): invalid 'type' (character) of argument
# Traceback:
#
# 1. my_mean(c("a", "a", "a"))

# %%
11 %% 3
# Out:
# [1] 2

# %%
remainder <- function(a,b=2){
    a%%b
    
}

# %%
remainder(45,4)
# Out:
# [1] 1

# %%
remainder(11,3)
# Out:
# [1] 2

# %%
remainder(34)
# Out:
# [1] 0

# %%
remainder(a=32,b=4)
# Out:
# [1] 0

# %%
remainder(b=3,a=35)
# Out:
# [1] 2

# %%
remainder(a=89)
# Out:
# [1] 1

# %%
num <- 45
divisor <- 3
remainder(num,divisor)
# Out:
# [1] 0

# %%
num <- 44
divisor <- 3
remainder(b=divisor,a=num)
# Out:
# [1] 2

# %%
simon_says <- function(...){
    paste("simon says",...)
}

# %%
simon_says("Hello R how r you")
# Out:
# [1] "simon says Hello R how r you"

# %%
add<- function(...){
    sum(c(...))
}

# %%
add(c(3,4,5))
# Out:
# [1] 12

# %%
add(c(45,23))
# Out:
# [1] 68

# %%
z=list(city="Mumbai",color="red")

# %%
z[["city"]]
# Out:
# [1] "Mumbai"

# %%
z[["color"]]
# Out:
# [1] "red"

# %%
some_func<- function(...){
    args<- list(...)
    city<- args[["city"]]
    return(city)
}

# %%
some_func(city="Mumbai")
# Out:
# [1] "Mumbai"

# %%
some_func<- function(...){
    args<- list(...)
    city<- args[["city"]]
    color<- args[["color"]]
    paste("I live in ",city,"and i like color",color)
    }

# %%
some_func(city="Pune",color="red")
# Out:
# [1] "I live in  Pune and i like color red"

# %%
"%concat%"<- function(left,right){
    paste(left,right)
}

# %%
"hello"%concat%"world"
# Out:
# [1] "hello world"

# %%
"Hello"%concat%"Everyone"%concat%"We are learning R language"
# Out:
# [1] "Hello Everyone We are learning R language"

# %%
d1<- Sys.Date()

# %%
class(d1)
# Out:
# [1] "Date"

# %%
d1
# Out:
# [1] "2019-12-12"

# %%
unclass(5)
# Out:
# [1] 5

# %%
unclass(d1)
# Out:
# [1] 18242

# %%
d2<- as.Date("1968-01-01")

# %%
d2
# Out:
# [1] "1968-01-01"

# %%
class(d2)
# Out:
# [1] "Date"

# %%
unclass(d2)
# Out:
# [1] -731

# %%
t1<- Sys.time()

# %%
t1
# Out:
# [1] "2019-12-12 09:15:27 UTC"

# %%
class(t1)
# Out:
# [1] "POSIXct" "POSIXt"

# %%
unclass(t1)
# Out:
# [1] 1576142128

# %%
t2<- as.POSIXlt(Sys.time())

# %%
t2
# Out:
# [1] "2019-12-12 09:15:27 UTC"

# %%
t2$min
# Out:
# [1] 15

# %%
t2$sec
# Out:
# [1] 27.79204

# %%
t2$hour
# Out:
# [1] 9

# %%
weekdays(t2)
# Out:
# [1] "Thursday"

# %%
months(t2)
# Out:
# [1] "December"

# %%
quarters(t2)
# Out:
# [1] "Q4"

# %%
t3<- "November 12,2019 02:11"

# %%
t4<- strptime(t3,"%B %d,&Y %H:%M")

# %%
t4
# Out:
# [1] NA

# %%
difftime(Sys.time(),t4,units="days")
# Out:
# Time difference of NA days

# %%
data(cars)

# %%
head(cars)
# Out:
#   speed dist
# 1 4      2
# 2 4     10
# 3 7      4
# 4 7     22
# 5 8     16
# 6 9     10

# %%
plot(cars)
# Out:
# plot without title

# %%
cars$speed
# Out:
#  [1]  4  4  7  7  8  9 10 10 10 11 11 12 12 12 12 13 13 13 13 14 14 14 14 15 15
# [26] 15 16 16 17 17 17 18 18 18 18 19 19 19 20 20 20 20 20 22 23 24 24 24 24 25

# %%
cars$dist
# Out:
#  [1]   2  10   4  22  16  10  18  26  34  17  28  14  20  24  28  26  34  34  46
# [20]  26  36  60  80  20  26  54  32  40  32  40  50  42  56  76  84  36  46  68
# [39]  32  48  52  56  64  66  54  70  92  93 120  85

# %%
plot(x=cars$speed,y=cars$dist)
# Out:
# plot without title

# %%
plot(x=cars$dist,y=cars$speed)
# Out:
# plot without title

# %%
plot(x=cars$dist,y=cars$speed,xlab="Distance",ylab="Speed")
# Out:
# plot without title

# %%
plot(x=cars$dist,y=cars$speed,xlab="Distance",ylab="Speed", main="Title" , col=4)#main= used to define the title, col= used to give color
# Out:
# Plot with title “Title”

# %%
plot(x=cars$dist,y=cars$speed,xlab="Distance",ylab="Speed", main="Title" , col=4,xlim=c(20,100),pch=65)  # xlim=used to retrive required data ie 20 to 100 here
# Out:
# Plot with title “Title”

# %%
data(mtcars)

# %%
head(mtcars)
# Out:
#                   mpg  cyl disp hp  drat wt    qsec  vs am gear carb
# Mazda RX4         21.0 6   160  110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag     21.0 6   160  110 3.90 2.875 17.02 0  1  4    4
# Datsun 710        22.8 4   108   93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive    21.4 6   258  110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout 18.7 8   360  175 3.15 3.440 17.02 0  0  3    2
# Valiant           18.1 6   225  105 2.76 3.460 20.22 1  0  3    1

# %%
boxplot(mtcars)
# Out:
# plot without title

# %%
boxplot(mtcars$mpg)
# Out:
# plot without title

# %%
boxplot(mtcars$disp, mtcars$hp)
# Out:
# plot without title

# %%
boxplot(mtcars$qsec, mtcars$vs, mtcars$am)
# Out:
# plot without title

# %%
hist(mtcars$mpg,xlab="mpg",main="Histogram",col=3)
# Out:
# Plot with title “Histogram”
